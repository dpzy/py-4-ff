# %% [markdown]
# # Ex2: [Matchup Adjustments](https://www.fantasyfutopia.com/python-for-fantasy-football-matchup-adjustment/)

# %% [markdown]
#  ## Table of Contents
#
# - **Loops and String Formatting**
#     * [1.1 Import CSV](#1csv)
#     * [1.2 String Formatting](#1string)
#          * [For Loop: Iterate Table Column Labelling](#1for)
#
# - **Merging Dataframes and Targeting**
#     * [2.1 Replace Table Entry](#2replace)
#     * [2.2 Subset and Merge Data - with pandas](#2subset)
#     * [2.3 Dropping Columns - with Dictionaries](#2drop)
#     * [2.4 Alternative to Merge - with map](#2map)
#
# - **Projected Stats**
#     * [3.1 Create Projected Stats](#3projected)
#     * [3.2 Decimal Places Rounding](#3decimal)
#
# - **Sense Checking**
#     * [4.1 Merge, Rename, Project](#4merge)
#     * [4.2 Visualize with Seaborn](#4seaborn)
#
# - **Functions**
#     * [5.1 Win and CS Odds Program](#5win)
#     * [asdf]()

# %% [markdown]
# ### 1.1 Import CSV and Data Set <a name="1csv"></a>

# %%
import pandas as pd

xg_dat = pd.read_csv('epl_xg.csv')
xg_dat
# Out:
#                        Team  Games   G  GA     xG    xGA   NPxG  NPxGA
# 0                   Arsenal      8  19  10  10.41  10.95  10.41  10.95
# 1               Bournemouth      8  16  12  16.08   9.25  12.27   7.73
# 2                  Brighton      8   9  13   9.49  14.71   6.44  12.43
# 3                   Burnley      8  10  12   7.69  14.11   7.69  13.35
# 4                   Cardiff      8   4  17   7.44  13.68   7.44  11.40
# 5                   Chelsea      8  18   5  15.72   8.59  13.44   8.59
# 6            Crystal Palace      8   5   9   7.02  11.56   7.02   9.28
# 7                   Everton      8  13  12   9.52   9.76   8.76   9.00
# 8                    Fulham      8   9  21   9.41  18.00   9.41  15.71
# 9              Huddersfield      8   4  17   4.75  13.26   4.75  11.74
# 10                Leicester      8  14  12   9.14   8.58   7.62   7.05
# 11                Liverpool      8  15   3  16.66   5.90  15.90   5.14
# 12          Manchester City      8  21   3  22.49   4.00  21.72   4.00
# 13        Manchester United      8  13  14  12.83  10.98  10.54  10.22
# 14                Newcastle      8   6  13   5.98  12.86   5.22  11.34
# 15              Southampton      8   6  14  10.61  14.02   9.09  13.26
# 16                Tottenham      8  15   7  14.79   9.66  13.27   9.66
# 17                  Watford      8  11  12  10.55  11.01  10.55  10.25
# 18                 West Ham      8   8  13   8.73  13.32   7.97  13.32
# 19  Wolverhampton Wanderers      8   9   6  11.06   6.15  11.06   6.15

# %%
xg_dat['GD'] = xg_dat['G'] - xg_dat['GA']
xg_dat['xGD'] = xg_dat['xG'] - xg_dat['xGA']
xg_dat['NPxGD'] =  xg_dat['NPxG'] - xg_dat['NPxGA']
xg_dat
# Out:
#                        Team  Games   G  GA     xG    xGA   NPxG  NPxGA  GD  \
# 0                   Arsenal      8  19  10  10.41  10.95  10.41  10.95   9
# 1               Bournemouth      8  16  12  16.08   9.25  12.27   7.73   4
# 2                  Brighton      8   9  13   9.49  14.71   6.44  12.43  -4
# 3                   Burnley      8  10  12   7.69  14.11   7.69  13.35  -2
# 4                   Cardiff      8   4  17   7.44  13.68   7.44  11.40 -13
# 5                   Chelsea      8  18   5  15.72   8.59  13.44   8.59  13
# 6            Crystal Palace      8   5   9   7.02  11.56   7.02   9.28  -4
# 7                   Everton      8  13  12   9.52   9.76   8.76   9.00   1
# 8                    Fulham      8   9  21   9.41  18.00   9.41  15.71 -12
# 9              Huddersfield      8   4  17   4.75  13.26   4.75  11.74 -13
# 10                Leicester      8  14  12   9.14   8.58   7.62   7.05   2
# 11                Liverpool      8  15   3  16.66   5.90  15.90   5.14  12
# 12          Manchester City      8  21   3  22.49   4.00  21.72   4.00  18
# 13        Manchester United      8  13  14  12.83  10.98  10.54  10.22  -1
# 14                Newcastle      8   6  13   5.98  12.86   5.22  11.34  -7
# 15              Southampton      8   6  14  10.61  14.02   9.09  13.26  -8
# 16                Tottenham      8  15   7  14.79   9.66  13.27   9.66   8
# 17                  Watford      8  11  12  10.55  11.01  10.55  10.25  -1
# 18                 West Ham      8   8  13   8.73  13.32   7.97  13.32  -5
# 19  Wolverhampton Wanderers      8   9   6  11.06   6.15  11.06   6.15   3
#
#       xGD  NPxGD
# 0   -0.54  -0.54
# 1    6.83   4.54
# 2   -5.22  -5.99
# 3   -6.42  -5.66
# 4   -6.24  -3.96
# 5    7.13   4.85
# 6   -4.54  -2.26
# 7   -0.24  -0.24
# 8   -8.59  -6.30
# 9   -8.51  -6.99
# 10   0.56   0.57
# 11  10.76  10.76
# 12  18.49  17.72
# 13   1.85   0.32
# 14  -6.88  -6.12
# 15  -3.41  -4.17
# 16   5.13   3.61
# 17  -0.46   0.30
# 18  -4.59  -5.35
# 19   4.91   4.91

# %% [markdown]
# ### 1.2  String Formating <a name="1string"></a>

# %%
# Print List's (xg_dat) Columns 
print(list(xg_dat))
# Out:
# ['Team', 'Games', 'G', 'GA', 'xG', 'xGA', 'NPxG', 'NPxGA', 'GD', 'xGD', 'NPxGD']

# %%
# Create a list of column names to target - for creating per game stat
cols = ['G', 'GA', 'xG', 'xGA', 'NPxG', 'NPxGA', 'GD', 'xGD', 'NPxGD']

# %% [markdown]
# ####  For Loop to Automate Table Column Labelling <a name="1for"></a>

# %%
for name in cols:
    xg_dat['%s-PG' % name] = xg_dat[name] / xg_dat['Games']
    
xg_dat
# Out:
#                        Team  Games   G  GA     xG    xGA   NPxG  NPxGA  GD  \
# 0                   Arsenal      8  19  10  10.41  10.95  10.41  10.95   9
# 1               Bournemouth      8  16  12  16.08   9.25  12.27   7.73   4
# 2                  Brighton      8   9  13   9.49  14.71   6.44  12.43  -4
# 3                   Burnley      8  10  12   7.69  14.11   7.69  13.35  -2
# 4                   Cardiff      8   4  17   7.44  13.68   7.44  11.40 -13
# 5                   Chelsea      8  18   5  15.72   8.59  13.44   8.59  13
# 6            Crystal Palace      8   5   9   7.02  11.56   7.02   9.28  -4
# 7                   Everton      8  13  12   9.52   9.76   8.76   9.00   1
# 8                    Fulham      8   9  21   9.41  18.00   9.41  15.71 -12
# 9              Huddersfield      8   4  17   4.75  13.26   4.75  11.74 -13
# 10                Leicester      8  14  12   9.14   8.58   7.62   7.05   2
# 11                Liverpool      8  15   3  16.66   5.90  15.90   5.14  12
# 12          Manchester City      8  21   3  22.49   4.00  21.72   4.00  18
# 13        Manchester United      8  13  14  12.83  10.98  10.54  10.22  -1
# 14                Newcastle      8   6  13   5.98  12.86   5.22  11.34  -7
# 15              Southampton      8   6  14  10.61  14.02   9.09  13.26  -8
# 16                Tottenham      8  15   7  14.79   9.66  13.27   9.66   8
# 17                  Watford      8  11  12  10.55  11.01  10.55  10.25  -1
# 18                 West Ham      8   8  13   8.73  13.32   7.97  13.32  -5
# 19  Wolverhampton Wanderers      8   9   6  11.06   6.15  11.06   6.15   3
#
#       xGD  NPxGD   G-PG  GA-PG    xG-PG   xGA-PG  NPxG-PG  NPxGA-PG  GD-PG  \
# 0   -0.54  -0.54  2.375  1.250  1.30125  1.36875  1.30125   1.36875  1.125
# 1    6.83   4.54  2.000  1.500  2.01000  1.15625  1.53375   0.96625  0.500
# 2   -5.22  -5.99  1.125  1.625  1.18625  1.83875  0.80500   1.55375 -0.500
# 3   -6.42  -5.66  1.250  1.500  0.96125  1.76375  0.96125   1.66875 -0.250
# 4   -6.24  -3.96  0.500  2.125  0.93000  1.71000  0.93000   1.42500 -1.625
# 5    7.13   4.85  2.250  0.625  1.96500  1.07375  1.68000   1.07375  1.625
# 6   -4.54  -2.26  0.625  1.125  0.87750  1.44500  0.87750   1.16000 -0.500
# 7   -0.24  -0.24  1.625  1.500  1.19000  1.22000  1.09500   1.12500  0.125
# 8   -8.59  -6.30  1.125  2.625  1.17625  2.25000  1.17625   1.96375 -1.500
# 9   -8.51  -6.99  0.500  2.125  0.59375  1.65750  0.59375   1.46750 -1.625
# 10   0.56   0.57  1.750  1.500  1.14250  1.07250  0.95250   0.88125  0.250
# 11  10.76  10.76  1.875  0.375  2.08250  0.73750  1.98750   0.64250  1.500
# 12  18.49  17.72  2.625  0.375  2.81125  0.50000  2.71500   0.50000  2.250
# 13   1.85   0.32  1.625  1.750  1.60375  1.37250  1.31750   1.27750 -0.125
# 14  -6.88  -6.12  0.750  1.625  0.74750  1.60750  0.65250   1.41750 -0.875
# 15  -3.41  -4.17  0.750  1.750  1.32625  1.75250  1.13625   1.65750 -1.000
# 16   5.13   3.61  1.875  0.875  1.84875  1.20750  1.65875   1.20750  1.000
# 17  -0.46   0.30  1.375  1.500  1.31875  1.37625  1.31875   1.28125 -0.125
# 18  -4.59  -5.35  1.000  1.625  1.09125  1.66500  0.99625   1.66500 -0.625
# 19   4.91   4.91  1.125  0.750  1.38250  0.76875  1.38250   0.76875  0.375
#
#      xGD-PG  NPxGD-PG
# 0  -0.06750  -0.06750
# 1   0.85375   0.56750
# 2  -0.65250  -0.74875
# 3  -0.80250  -0.70750
# 4  -0.78000  -0.49500
# 5   0.89125   0.60625
# 6  -0.56750  -0.28250
# 7  -0.03000  -0.03000
# 8  -1.07375  -0.78750
# 9  -1.06375  -0.87375
# 10  0.07000   0.07125
# 11  1.34500   1.34500
# 12  2.31125   2.21500
# 13  0.23125   0.04000
# 14 -0.86000  -0.76500
# 15 -0.42625  -0.52125
# 16  0.64125   0.45125
# 17 -0.05750   0.03750
# 18 -0.57375  -0.66875
# 19  0.61375   0.61375

# %% [markdown]
# ------------

# %% [markdown]
# ## 2.1 Replace Data Entries  <a name="2replace"></a>

# %%
#Read CSV
matchup = pd.read_csv('epl_fixtures.csv')
matchup
# Out:
#          Home_Team          Away_Team
# 0          Chelsea  Manchester United
# 1      Bournemouth        Southampton
# 2          Cardiff             Fulham
# 3  Manchester City            Burnley
# 4        Newcastle           Brighton
# 5         West Ham          Tottenham
# 6           Wolves            Watford
# 7     Huddersfield          Liverpool
# 8          Everton     Crystal Palace
# 9          Arsenal          Leicester

# %%
#[.replace] Funciton
matchup = matchup.replace('Wolves', 'Wolverhampton Wanderers')
matchup
# Out:
#                  Home_Team          Away_Team
# 0                  Chelsea  Manchester United
# 1              Bournemouth        Southampton
# 2                  Cardiff             Fulham
# 3          Manchester City            Burnley
# 4                Newcastle           Brighton
# 5                 West Ham          Tottenham
# 6  Wolverhampton Wanderers            Watford
# 7             Huddersfield          Liverpool
# 8                  Everton     Crystal Palace
# 9                  Arsenal          Leicester

# %% [markdown]
# ## 2.2 Subset and Merge Dataframes - with Pandas
# <a name="2subset"></a>

# %%
#Subset Data from xg_dat
xg_dat_pg = xg_dat[['Team', 'xG-PG', 'xGA-PG']]
xg_dat_pg
# Out:
#                        Team    xG-PG   xGA-PG
# 0                   Arsenal  1.30125  1.36875
# 1               Bournemouth  2.01000  1.15625
# 2                  Brighton  1.18625  1.83875
# 3                   Burnley  0.96125  1.76375
# 4                   Cardiff  0.93000  1.71000
# 5                   Chelsea  1.96500  1.07375
# 6            Crystal Palace  0.87750  1.44500
# 7                   Everton  1.19000  1.22000
# 8                    Fulham  1.17625  2.25000
# 9              Huddersfield  0.59375  1.65750
# 10                Leicester  1.14250  1.07250
# 11                Liverpool  2.08250  0.73750
# 12          Manchester City  2.81125  0.50000
# 13        Manchester United  1.60375  1.37250
# 14                Newcastle  0.74750  1.60750
# 15              Southampton  1.32625  1.75250
# 16                Tottenham  1.84875  1.20750
# 17                  Watford  1.31875  1.37625
# 18                 West Ham  1.09125  1.66500
# 19  Wolverhampton Wanderers  1.38250  0.76875

# %%
# Merge and Match 2 Dataframes (pandas)
matchup = pd.merge(matchup, xg_dat_pg, left_on='Home_Team', right_on='Team')
matchup
# Out:
#                  Home_Team          Away_Team                     Team  \
# 0                  Chelsea  Manchester United                  Chelsea
# 1              Bournemouth        Southampton              Bournemouth
# 2                  Cardiff             Fulham                  Cardiff
# 3          Manchester City            Burnley          Manchester City
# 4                Newcastle           Brighton                Newcastle
# 5                 West Ham          Tottenham                 West Ham
# 6  Wolverhampton Wanderers            Watford  Wolverhampton Wanderers
# 7             Huddersfield          Liverpool             Huddersfield
# 8                  Everton     Crystal Palace                  Everton
# 9                  Arsenal          Leicester                  Arsenal
#
#      xG-PG   xGA-PG
# 0  1.96500  1.07375
# 1  2.01000  1.15625
# 2  0.93000  1.71000
# 3  2.81125  0.50000
# 4  0.74750  1.60750
# 5  1.09125  1.66500
# 6  1.38250  0.76875
# 7  0.59375  1.65750
# 8  1.19000  1.22000
# 9  1.30125  1.36875

# %%
#Iterate Merge with the same value and see what happens (pandas)
matchup = pd.merge(matchup, xg_dat_pg, left_on='Away_Team', right_on='Team')
matchup
# Out:
#                  Home_Team          Away_Team                   Team_x  \
# 0                  Chelsea  Manchester United                  Chelsea
# 1              Bournemouth        Southampton              Bournemouth
# 2                  Cardiff             Fulham                  Cardiff
# 3          Manchester City            Burnley          Manchester City
# 4                Newcastle           Brighton                Newcastle
# 5                 West Ham          Tottenham                 West Ham
# 6  Wolverhampton Wanderers            Watford  Wolverhampton Wanderers
# 7             Huddersfield          Liverpool             Huddersfield
# 8                  Everton     Crystal Palace                  Everton
# 9                  Arsenal          Leicester                  Arsenal
#
#    xG-PG_x  xGA-PG_x             Team_y  xG-PG_y  xGA-PG_y
# 0  1.96500   1.07375  Manchester United  1.60375   1.37250
# 1  2.01000   1.15625        Southampton  1.32625   1.75250
# 2  0.93000   1.71000             Fulham  1.17625   2.25000
# 3  2.81125   0.50000            Burnley  0.96125   1.76375
# 4  0.74750   1.60750           Brighton  1.18625   1.83875
# 5  1.09125   1.66500          Tottenham  1.84875   1.20750
# 6  1.38250   0.76875            Watford  1.31875   1.37625
# 7  0.59375   1.65750          Liverpool  2.08250   0.73750
# 8  1.19000   1.22000     Crystal Palace  0.87750   1.44500
# 9  1.30125   1.36875          Leicester  1.14250   1.07250

# %% [markdown]
# ## 2.3 Dropping Columns - with Dictionaries
# <a name="2drop"></a>

# %%
#Simple Drop Column
matchup = matchup.drop(['Team_x', 'Team_y'], axis=1)
matchup
# Out:
#                  Home_Team          Away_Team  xG-PG_x  xGA-PG_x  xG-PG_y  \
# 0                  Chelsea  Manchester United  1.96500   1.07375  1.60375
# 1              Bournemouth        Southampton  2.01000   1.15625  1.32625
# 2                  Cardiff             Fulham  0.93000   1.71000  1.17625
# 3          Manchester City            Burnley  2.81125   0.50000  0.96125
# 4                Newcastle           Brighton  0.74750   1.60750  1.18625
# 5                 West Ham          Tottenham  1.09125   1.66500  1.84875
# 6  Wolverhampton Wanderers            Watford  1.38250   0.76875  1.31875
# 7             Huddersfield          Liverpool  0.59375   1.65750  2.08250
# 8                  Everton     Crystal Palace  1.19000   1.22000  0.87750
# 9                  Arsenal          Leicester  1.30125   1.36875  1.14250
#
#    xGA-PG_y
# 0   1.37250
# 1   1.75250
# 2   2.25000
# 3   1.76375
# 4   1.83875
# 5   1.20750
# 6   1.37625
# 7   0.73750
# 8   1.44500
# 9   1.07250

# %%
# Using Dictionary to Group-rename Column names

namechange = {'xG-PG_x': 'xG-PG_home', 'xGA-PG_x': 'xGA-PG_home', 'xG-PG_y': 'xG-PG_away', 'xGA-PG_y': 'xGA-PG_away'}
matchup = matchup.rename(columns=namechange)
matchup

## Alternative
## fixtures = fixtures.rename(columns={'xG_pg_x': 'xG_pg_home_team', 
##'xGA_pg_x': 'xGA_pg_home_team', 'xG_pg_y': 'xG_pg_away_team', 'xGA_pg_y': 'xGA_pg_awaybbb_team'})
# Out:
#                  Home_Team          Away_Team  xG-PG_home  xGA-PG_home  \
# 0                  Chelsea  Manchester United     1.96500      1.07375
# 1              Bournemouth        Southampton     2.01000      1.15625
# 2                  Cardiff             Fulham     0.93000      1.71000
# 3          Manchester City            Burnley     2.81125      0.50000
# 4                Newcastle           Brighton     0.74750      1.60750
# 5                 West Ham          Tottenham     1.09125      1.66500
# 6  Wolverhampton Wanderers            Watford     1.38250      0.76875
# 7             Huddersfield          Liverpool     0.59375      1.65750
# 8                  Everton     Crystal Palace     1.19000      1.22000
# 9                  Arsenal          Leicester     1.30125      1.36875
#
#    xG-PG_away  xGA-PG_away
# 0     1.60375      1.37250
# 1     1.32625      1.75250
# 2     1.17625      2.25000
# 3     0.96125      1.76375
# 4     1.18625      1.83875
# 5     1.84875      1.20750
# 6     1.31875      1.37625
# 7     2.08250      0.73750
# 8     0.87750      1.44500
# 9     1.14250      1.07250

# %% [markdown]
# ## 2.4 Alternative to Merging Dataframes  -  with map <a name="2map"></a>

# %%
#Redo CSV Imports
mapup = pd.read_csv("epl_fixtures.csv")
mapup = mapup.replace('Wolves', 'Wolverhampton Wanderers')
mapup
# Out:
#                  Home_Team          Away_Team
# 0                  Chelsea  Manchester United
# 1              Bournemouth        Southampton
# 2                  Cardiff             Fulham
# 3          Manchester City            Burnley
# 4                Newcastle           Brighton
# 5                 West Ham          Tottenham
# 6  Wolverhampton Wanderers            Watford
# 7             Huddersfield          Liverpool
# 8                  Everton     Crystal Palace
# 9                  Arsenal          Leicester

# %%
# Set dataframe with 'Team' as Index
xg_pg = xg_dat_pg.copy(deep=True)
xg_pg.set_index('Team', inplace=True)
xg_pg
# Out:
#                            xG-PG   xGA-PG
# Team
# Arsenal                  1.30125  1.36875
# Bournemouth              2.01000  1.15625
# Brighton                 1.18625  1.83875
# Burnley                  0.96125  1.76375
# Cardiff                  0.93000  1.71000
# Chelsea                  1.96500  1.07375
# Crystal Palace           0.87750  1.44500
# Everton                  1.19000  1.22000
# Fulham                   1.17625  2.25000
# Huddersfield             0.59375  1.65750
# Leicester                1.14250  1.07250
# Liverpool                2.08250  0.73750
# Manchester City          2.81125  0.50000
# Manchester United        1.60375  1.37250
# Newcastle                0.74750  1.60750
# Southampton              1.32625  1.75250
# Tottenham                1.84875  1.20750
# Watford                  1.31875  1.37625
# West Ham                 1.09125  1.66500
# Wolverhampton Wanderers  1.38250  0.76875

# %%
#Map a Sub-dataset to Main Dataset
mapup['xG-PG_home'] = mapup['Home_Team'].map(xg_pg['xG-PG'])

## ie: Create new Column = find the column of X to match, check the index, and deliver data in Y.
mapup
# Out:
#                  Home_Team          Away_Team  xG-PG_home
# 0                  Chelsea  Manchester United     1.96500
# 1              Bournemouth        Southampton     2.01000
# 2                  Cardiff             Fulham     0.93000
# 3          Manchester City            Burnley     2.81125
# 4                Newcastle           Brighton     0.74750
# 5                 West Ham          Tottenham     1.09125
# 6  Wolverhampton Wanderers            Watford     1.38250
# 7             Huddersfield          Liverpool     0.59375
# 8                  Everton     Crystal Palace     1.19000
# 9                  Arsenal          Leicester     1.30125

# %%
##Repeat for all 
mapup['xGA-PG_home'] = mapup['Home_Team'].map(xg_pg['xGA-PG'])
mapup['xG-PG_away'] = mapup['Away_Team'].map(xg_pg['xG-PG'])
mapup['xGA-PG_away'] = mapup['Away_Team'].map(xg_pg['xGA-PG'])
mapup
# Out:
#                  Home_Team          Away_Team  xG-PG_home  xGA-PG_home  \
# 0                  Chelsea  Manchester United     1.96500      1.07375
# 1              Bournemouth        Southampton     2.01000      1.15625
# 2                  Cardiff             Fulham     0.93000      1.71000
# 3          Manchester City            Burnley     2.81125      0.50000
# 4                Newcastle           Brighton     0.74750      1.60750
# 5                 West Ham          Tottenham     1.09125      1.66500
# 6  Wolverhampton Wanderers            Watford     1.38250      0.76875
# 7             Huddersfield          Liverpool     0.59375      1.65750
# 8                  Everton     Crystal Palace     1.19000      1.22000
# 9                  Arsenal          Leicester     1.30125      1.36875
#
#    xG-PG_away  xGA-PG_away
# 0     1.60375      1.37250
# 1     1.32625      1.75250
# 2     1.17625      2.25000
# 3     0.96125      1.76375
# 4     1.18625      1.83875
# 5     1.84875      1.20750
# 6     1.31875      1.37625
# 7     2.08250      0.73750
# 8     0.87750      1.44500
# 9     1.14250      1.07250

# %% [markdown]
# -------------

# %% [markdown]
# # Projecting Stats & Visualizing It

# %% [markdown]
# ## 3.1 Create Projected Stats <a name="3projected"></a>

# %%
## The Formula: (attacking xg * defending xGA) / (average xG)
## Tables we need: from mapup >> adjustmap
### Stats we need: xg_avg

xg_avg = xg_dat_pg['xG-PG'].mean()
adjustmap = mapup.copy(deep=True)
adjustmap
# Out:
#                  Home_Team          Away_Team  xG-PG_home  xGA-PG_home  \
# 0                  Chelsea  Manchester United     1.96500      1.07375
# 1              Bournemouth        Southampton     2.01000      1.15625
# 2                  Cardiff             Fulham     0.93000      1.71000
# 3          Manchester City            Burnley     2.81125      0.50000
# 4                Newcastle           Brighton     0.74750      1.60750
# 5                 West Ham          Tottenham     1.09125      1.66500
# 6  Wolverhampton Wanderers            Watford     1.38250      0.76875
# 7             Huddersfield          Liverpool     0.59375      1.65750
# 8                  Everton     Crystal Palace     1.19000      1.22000
# 9                  Arsenal          Leicester     1.30125      1.36875
#
#    xG-PG_away  xGA-PG_away
# 0     1.60375      1.37250
# 1     1.32625      1.75250
# 2     1.17625      2.25000
# 3     0.96125      1.76375
# 4     1.18625      1.83875
# 5     1.84875      1.20750
# 6     1.31875      1.37625
# 7     2.08250      0.73750
# 8     0.87750      1.44500
# 9     1.14250      1.07250

# %%
#Create an Adjusted xG Score for home team
adjustmap['xG-PG_ahome'] = adjustmap['xG-PG_home'] * adjustmap['xGA-PG_away'] / xg_avg
adjustmap
# Out:
#                  Home_Team          Away_Team  xG-PG_home  xGA-PG_home  \
# 0                  Chelsea  Manchester United     1.96500      1.07375
# 1              Bournemouth        Southampton     2.01000      1.15625
# 2                  Cardiff             Fulham     0.93000      1.71000
# 3          Manchester City            Burnley     2.81125      0.50000
# 4                Newcastle           Brighton     0.74750      1.60750
# 5                 West Ham          Tottenham     1.09125      1.66500
# 6  Wolverhampton Wanderers            Watford     1.38250      0.76875
# 7             Huddersfield          Liverpool     0.59375      1.65750
# 8                  Everton     Crystal Palace     1.19000      1.22000
# 9                  Arsenal          Leicester     1.30125      1.36875
#
#    xG-PG_away  xGA-PG_away  xG-PG_ahome
# 0     1.60375      1.37250     1.958134
# 1     1.32625      1.75250     2.557535
# 2     1.17625      2.25000     1.519263
# 3     0.96125      1.76375     3.600012
# 4     1.18625      1.83875     0.997933
# 5     1.84875      1.20750     0.956707
# 6     1.31875      1.37625     1.381433
# 7     2.08250      0.73750     0.317931
# 8     0.87750      1.44500     1.248482
# 9     1.14250      1.07250     1.013271

# %%
adjustmap['xG-PG_aaway'] = adjustmap['xG-PG_away'] * adjustmap['xGA-PG_home'] / xg_avg
adjustmap
# Out:
#                  Home_Team          Away_Team  xG-PG_home  xGA-PG_home  \
# 0                  Chelsea  Manchester United     1.96500      1.07375
# 1              Bournemouth        Southampton     2.01000      1.15625
# 2                  Cardiff             Fulham     0.93000      1.71000
# 3          Manchester City            Burnley     2.81125      0.50000
# 4                Newcastle           Brighton     0.74750      1.60750
# 5                 West Ham          Tottenham     1.09125      1.66500
# 6  Wolverhampton Wanderers            Watford     1.38250      0.76875
# 7             Huddersfield          Liverpool     0.59375      1.65750
# 8                  Everton     Crystal Palace     1.19000      1.22000
# 9                  Arsenal          Leicester     1.30125      1.36875
#
#    xG-PG_away  xGA-PG_away  xG-PG_ahome  xG-PG_aaway
# 0     1.60375      1.37250     1.958134     1.250280
# 1     1.32625      1.75250     2.557535     1.113383
# 2     1.17625      2.25000     1.519263     1.460371
# 3     0.96125      1.76375     3.600012     0.348959
# 4     1.18625      1.83875     0.997933     1.384506
# 5     1.84875      1.20750     0.956707     2.234909
# 6     1.31875      1.37625     1.381433     0.736063
# 7     2.08250      0.73750     0.317931     2.506144
# 8     0.87750      1.44500     1.248482     0.777275
# 9     1.14250      1.07250     1.013271     1.135397

# %% [markdown]
# ## 3.2 Decimal Places Rounding <a name="3decimal"></a>

# %%
#Create Dictionary of ColNames to target, and desired decimal places
targetd = {'xG-PG_home':2, 'xGA-PG_home': 2, 'xG-PG_away': 2, 'xGA-PG_away': 2, 'xG-PG_ahome': 3, 'xG-PG_aaway': 3}
adjustmap = adjustmap.round(targetd)
adjustmap
# Out:
#                  Home_Team          Away_Team  xG-PG_home  xGA-PG_home  \
# 0                  Chelsea  Manchester United        1.96         1.07
# 1              Bournemouth        Southampton        2.01         1.16
# 2                  Cardiff             Fulham        0.93         1.71
# 3          Manchester City            Burnley        2.81         0.50
# 4                Newcastle           Brighton        0.75         1.61
# 5                 West Ham          Tottenham        1.09         1.66
# 6  Wolverhampton Wanderers            Watford        1.38         0.77
# 7             Huddersfield          Liverpool        0.59         1.66
# 8                  Everton     Crystal Palace        1.19         1.22
# 9                  Arsenal          Leicester        1.30         1.37
#
#    xG-PG_away  xGA-PG_away  xG-PG_ahome  xG-PG_aaway
# 0        1.60         1.37        1.958        1.250
# 1        1.33         1.75        2.558        1.113
# 2        1.18         2.25        1.519        1.460
# 3        0.96         1.76        3.600        0.349
# 4        1.19         1.84        0.998        1.385
# 5        1.85         1.21        0.957        2.235
# 6        1.32         1.38        1.381        0.736
# 7        2.08         0.74        0.318        2.506
# 8        0.88         1.44        1.248        0.777
# 9        1.14         1.07        1.013        1.135

# %% [markdown]
# --------------

# %% [markdown]
# # Sense Checking

# %% [markdown]
# ## 4.1 Merge, Rename, Project <a name="4merge"></a>

# %%
#Read CSV
booky = pd.read_csv('epl_week_9_implied_goals.csv')
booky
# Out:
#                  Home_Team          Away_Team  Bookies_Home_Goals  \
# 0                  Chelsea  Manchester United               1.869
# 1              Bournemouth        Southampton               1.632
# 2                  Cardiff             Fulham               1.440
# 3          Manchester City            Burnley               3.536
# 4                Newcastle           Brighton               1.261
# 5                 West Ham          Tottenham               1.172
# 6  Wolverhampton Wanderers            Watford               1.626
# 7             Huddersfield          Liverpool               0.554
# 8                  Everton     Crystal Palace               1.645
# 9                  Arsenal          Leicester               2.237
#
#    Bookies_Away_Goals
# 0               1.070
# 1               1.219
# 2               1.378
# 3               0.506
# 4               0.951
# 5               1.899
# 6               0.881
# 7               2.377
# 8               1.016
# 9               1.032

# %%
#Merge Dataframes
adjustmap = pd.merge(adjustmap, booky)
adjustmap
# Out:
#                  Home_Team          Away_Team  xG-PG_home  xGA-PG_home  \
# 0                  Chelsea  Manchester United        1.96         1.07
# 1              Bournemouth        Southampton        2.01         1.16
# 2                  Cardiff             Fulham        0.93         1.71
# 3          Manchester City            Burnley        2.81         0.50
# 4                Newcastle           Brighton        0.75         1.61
# 5                 West Ham          Tottenham        1.09         1.66
# 6  Wolverhampton Wanderers            Watford        1.38         0.77
# 7             Huddersfield          Liverpool        0.59         1.66
# 8                  Everton     Crystal Palace        1.19         1.22
# 9                  Arsenal          Leicester        1.30         1.37
#
#    xG-PG_away  xGA-PG_away  xG-PG_ahome  xG-PG_aaway  Bookies_Home_Goals  \
# 0        1.60         1.37        1.958        1.250               1.869
# 1        1.33         1.75        2.558        1.113               1.632
# 2        1.18         2.25        1.519        1.460               1.440
# 3        0.96         1.76        3.600        0.349               3.536
# 4        1.19         1.84        0.998        1.385               1.261
# 5        1.85         1.21        0.957        2.235               1.172
# 6        1.32         1.38        1.381        0.736               1.626
# 7        2.08         0.74        0.318        2.506               0.554
# 8        0.88         1.44        1.248        0.777               1.645
# 9        1.14         1.07        1.013        1.135               2.237
#
#    Bookies_Away_Goals
# 0               1.070
# 1               1.219
# 2               1.378
# 3               0.506
# 4               0.951
# 5               1.899
# 6               0.881
# 7               2.377
# 8               1.016
# 9               1.032

# %%
#Find Difference in Odds
adjustmap = adjustmap.rename(columns={'Bookies_Home_Goals': 'Booky_home', 'Bookies_Away_Goals': 'Booky_away'})
adjustmap['home-xG-dif'] = adjustmap['xG-PG_ahome'] - adjustmap['Booky_home']
adjustmap['away-xG-dif'] = adjustmap['xG-PG_aaway'] - adjustmap['Booky_away']
adjustmap
# Out:
#                  Home_Team          Away_Team  xG-PG_home  xGA-PG_home  \
# 0                  Chelsea  Manchester United        1.96         1.07
# 1              Bournemouth        Southampton        2.01         1.16
# 2                  Cardiff             Fulham        0.93         1.71
# 3          Manchester City            Burnley        2.81         0.50
# 4                Newcastle           Brighton        0.75         1.61
# 5                 West Ham          Tottenham        1.09         1.66
# 6  Wolverhampton Wanderers            Watford        1.38         0.77
# 7             Huddersfield          Liverpool        0.59         1.66
# 8                  Everton     Crystal Palace        1.19         1.22
# 9                  Arsenal          Leicester        1.30         1.37
#
#    xG-PG_away  xGA-PG_away  xG-PG_ahome  xG-PG_aaway  Booky_home  Booky_away  \
# 0        1.60         1.37        1.958        1.250       1.869       1.070
# 1        1.33         1.75        2.558        1.113       1.632       1.219
# 2        1.18         2.25        1.519        1.460       1.440       1.378
# 3        0.96         1.76        3.600        0.349       3.536       0.506
# 4        1.19         1.84        0.998        1.385       1.261       0.951
# 5        1.85         1.21        0.957        2.235       1.172       1.899
# 6        1.32         1.38        1.381        0.736       1.626       0.881
# 7        2.08         0.74        0.318        2.506       0.554       2.377
# 8        0.88         1.44        1.248        0.777       1.645       1.016
# 9        1.14         1.07        1.013        1.135       2.237       1.032
#
#    home-xG-dif  away-xG-dif
# 0        0.089        0.180
# 1        0.926       -0.106
# 2        0.079        0.082
# 3        0.064       -0.157
# 4       -0.263        0.434
# 5       -0.215        0.336
# 6       -0.245       -0.145
# 7       -0.236        0.129
# 8       -0.397       -0.239
# 9       -1.224        0.103

# %% [markdown]
# ## 4.2 Visualize with Seaborn <a name="4seaborn"></a>

# %%
#Import Libraries
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Plot 2 graphs. sharing the same x-axis attributes, different ys
## 1. Call on matplotlibs function (f) and generate 2 x-axis (ax1, ax2)
## 2. Set the same kind of dimensions with [figsize]
## 3. Using [nrows=2, sharex=True], we can compound 2 plots into 1 function (f)
f, (ax1, ax2) = plt.subplots(nrows=2, figsize=(8,10), sharex=True)

#Seaborn Settings
sns.set(style="whitegrid")
sns.set_color_codes("muted")

#Seaborn Plot
sns.barplot(x='home-xG-dif', y='Home_Team', data = adjustmap, color ='g', ax=ax1)
sns.barplot(x='away-xG-dif', y='Away_Team', data = adjustmap, color ='r', ax=ax2)

#Seaborn Axis
ax1.set(xlabel="", ylabel="", title="Home Teams")
ax2.set(xlabel="Deviation b/w Bookie & xG Odds", ylabel="", title="Away Teams")

#Seaborn Despine
sns.despine(left=True, bottom = True)

# %% [markdown]
# ------------

# %% [markdown]
# # Functions
#
# ## 5.1 Creating Win & CS Odds <a name="5win"></a>
#
# Enclosing code within a function, allows users to input new datasets repeatedly, without duplication of code.

# %%
import numpy as np

def win_cs(df, home_goals, away_goals, n=10000)
"""Generate win% and clean sheet% for each row of dataframe (df), 
   using average goal totals from 'home_goals' & 'away_goals',
   and repeating it by n = no. of sims to run, defaults at 10000"""

    #1. Create Blank List for Data to be input into
    home_win_list = []
    away_win_list = []
    home_cs_list = []
    away_cs_list = []
    
    #2. Iterate through each row in given dataframe
    for i in range(len(df)):
        avg_home_goals = df.iloc[i][home_goals]
        avg_away_goals = df.iloc[i][away_goals]
        
        #3. Simulate Home & Away Games by n times, assuming Poisson distribution
        home_goals_sim = np.random.poisson(avg_home_goals, n)
        away_goals_sim = np.random.poisson(avg_away_goals, n)
        
        #4. Create a new dataframe (sim) that aggregates sample result
        sim = pd.dataframe({'Home_score': home_goals_sim, 'Away_score': away_goals_sim})
